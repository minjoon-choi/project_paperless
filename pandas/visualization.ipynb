# %%
import pymysql
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

db = pymysql.connect(host='127.0.0.1', port=3306, user='root', passwd='', db='test', charset='utf8')

print ("MySQL connector library import succeed")
db
cursor = db.cursor()
cursor
# Out:
# MySQL connector library import succeed

# %%
sql = 'SELECT user_group_name,  SUM(performance) FROM gr_list GROUP BY user_group_name;'

# %%
cursor.execute(sql)
result = cursor.fetchall()

# %%
print(result)
# Out:
# (('가공원료팀', 16815691055.009857), ('간접구매팀', 2471587394.0728884), ('상품소싱팀', 1088711606.5789447), ('설비팀', 29228082686.828125), ('신선식품팀', 29836654026.439777), ('인테리어팀', 3752828023.0), ('포장재팀', 9639313670.38118), ('해외전략구매팀', 12478617082.273865))

# %%
df = pd.DataFrame(result)
df.columns = ['user_group_name', 'performance']

plt.barh(df['user_group_name'], df['performance'])
# Out:
# <BarContainer object of 8 artists>
